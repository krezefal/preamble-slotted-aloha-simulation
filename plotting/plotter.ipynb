# %%
import matplotlib.pyplot as plt

subs = 100
lambs = [ 0.0964, 0.2008,  0.2921, 0.371, 0.3688,  0.3769, 0.3787, 0.3773, 0.3772, 0.3772]
delays = [6.58,
          43.124,
          104,
          351,
          1153,
          1982,
          2398,
          2647,
          2854,
          3197]

# %%
plt.figure(1)
plt.title('Avg delay dependency on Lambda')
plt.xlabel('Avg λ')
plt.ylabel('d(λ)')
plt.grid(True)

plt.plot(lambs, delays)

# %%
lambdas_in = [0.101, 0.2079, 0.3023, 0.4001, 0.506, 0.5939, 0.686, 0.7974, 0.8955, 0.9786]
lambdas_out = [0.0976, 0.1911, 0.2879, 0.3475, 0.3619, 0.3697, 0.3591, 0.3624, 0.3667, 0.378]

plt.figure(2)
plt.title('Lambda_out dependency on Lambda_in')
plt.xlabel('λ_in')
plt.ylabel('λ_out')
plt.grid(True)

plt.plot(lambdas_in, lambdas_out)

plt.figure(3)
plt.title('Lambda_in and Lambda_out')
plt.xlabel('λ')
plt.grid(True)

plt.plot(lambs, lambdas_in)
plt.plot(lambs, lambdas_out)

plt.legend(['λin', 'λout'])
